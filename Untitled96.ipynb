# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("C:/Users/SPTINT-20/Desktop/dataset1/survey_lung_cancer_SVM.csv")

# %%
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data['GENDER']=data['GENDER'].map({'M':1,'F':0})
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
new_data=scaler.fit_transform(data.drop(labels=['LUNG_CANCER'],axis=1))

# %%
data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data['GENDER']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 304    0
# 305    1
# 306    1
# 307    1
# 308    1
# Name: GENDER, Length: 309, dtype: int64

# %%
data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
cor=data.corr()
f,ax=plt.subplots(figsize=[12,8])
sns.heatmap(cor,annot=True,cmap='RdYlGn',ax=ax)
# Out:
# <AxesSubplot:>

# %%
x=data.iloc[:,:15]
y=data.iloc[:,15:]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
y
# Out:
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES
#
# [309 rows x 1 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import classification_report
print('classification',classification_report(y_pred,y_test))
# Out:
# classification               precision    recall  f1-score   support
#
#           NO       0.43      0.50      0.46         6
#          YES       0.95      0.93      0.94        56
#
#     accuracy                           0.89        62
#    macro avg       0.69      0.71      0.70        62
# weighted avg       0.90      0.89      0.89        62
